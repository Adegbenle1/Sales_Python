# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('1000000 HRA Records.csv', index_col =0).head()

# %%
df.head()
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 58         No  Travel_Frequently        200                Hardware
# 18        Yes      Travel_Rarely        720                   Sales
# 25         No         Non-Travel       1406                 Support
# 38        Yes  Travel_Frequently       1316                Software
# 35         No      Travel_Rarely        711  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# Age
# 58                 13          5     Life Sciences              1
# 18                 34          2  Technical Degree              1
# 25                  3          2     Life Sciences              1
# 38                 19          5             Other              1
# 35                 28          4  Technical Degree              1
#
#      EmployeeNumber  EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# Age                                           ...
# ...

# %%
df.head(8)
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 58         No  Travel_Frequently        200                Hardware
# 18        Yes      Travel_Rarely        720                   Sales
# 25         No         Non-Travel       1406                 Support
# 38        Yes  Travel_Frequently       1316                Software
# 35         No      Travel_Rarely        711  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# Age
# 58                 13          5     Life Sciences              1
# 18                 34          2  Technical Degree              1
# 25                  3          2     Life Sciences              1
# 38                 19          5             Other              1
# 35                 28          4  Technical Degree              1
#
#      EmployeeNumber  EnvironmentSatisfaction  ... RelationshipSatisfaction  \
# Age                                           ...
# ...

# %%
 df =pd.read_csv('1000000 HRA Records.csv', na_values=['', '?', '-']) # write na

# %%
df.describe()
# Out:
#                   Age       DailyRate  DistanceFromHome       Education  \
# count  1000000.000000  1000000.000000    1000000.000000  1000000.000000
# mean        38.976191      799.498643         25.506090        2.999455
# std         12.403615      404.493606         14.423455        1.413818
# min         18.000000      100.000000          1.000000        1.000000
# 25%         28.000000      449.000000         13.000000        2.000000
# 50%         39.000000      799.000000         25.000000        3.000000
# 75%         50.000000     1150.000000         38.000000        4.000000
# max         60.000000     1500.000000         50.000000        5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction      HourlyRate  \
# count      1000000.0  1000000.000000           1000000.000000  1000000.000000
# mean             1.0   500000.500000                 2.501423      115.018539
# std              0.0   288675.278933                 1.117929       49.354764
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0        58        No  Travel_Frequently        200                Hardware
# 1        18       Yes      Travel_Rarely        720                   Sales
# 2        25        No         Non-Travel       1406                 Support
# 3        38       Yes  Travel_Frequently       1316                Software
# 4        35        No      Travel_Rarely        711  Research & Development
# ...     ...       ...                ...        ...                     ...
# 999995   19       Yes      Travel_Rarely        389                   Sales
# 999996   24        No         Non-Travel       1248                Hardware
# 999997   55        No         Non-Travel       1298                 Support
# 999998   44       Yes         Non-Travel       1065  Research & Development
# 999999   19       Yes         Non-Travel        776  Research & Development
#
# ...

# %%
falsy_values =(0, False, None, '',[], {})

# %%
any(falsy_values)
# Out:
# False

# %%
pd.notnull(df)
# Out:
#          Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0       True       True            True       True        True
# 1       True       True            True       True        True
# 2       True       True            True       True        True
# 3       True       True            True       True        True
# 4       True       True            True       True        True
# ...      ...        ...             ...        ...         ...
# 999995  True       True            True       True        True
# 999996  True       True            True       True        True
# 999997  True       True            True       True        True
# 999998  True       True            True       True        True
# 999999  True       True            True       True        True
#
#         DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                   True       True            True           True
# 1                   True       True            True           True
# ...

# %%
pd.isnull(df)
# Out:
#           Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0       False      False           False      False       False
# 1       False      False           False      False       False
# 2       False      False           False      False       False
# 3       False      False           False      False       False
# 4       False      False           False      False       False
# ...       ...        ...             ...        ...         ...
# 999995  False      False           False      False       False
# 999996  False      False           False      False       False
# 999997  False      False           False      False       False
# 999998  False      False           False      False       False
# 999999  False      False           False      False       False
#
#         DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                  False      False           False          False
# ...

# %%
len(df)
# Out:
# 1000000

# %%
df.count()
# Out:
# Age                         1000000
# Attrition                   1000000
# BusinessTravel              1000000
# DailyRate                   1000000
# Department                  1000000
# DistanceFromHome            1000000
# Education                   1000000
# EducationField              1000000
# EmployeeCount               1000000
# EmployeeNumber              1000000
# EnvironmentSatisfaction     1000000
# Gender                      1000000
# HourlyRate                  1000000
# JobInvolvement              1000000
# JobLevel                    1000000
# JobRole                     1000000
# JobSatisfaction             1000000
# MaritalStatus               1000000
# MonthlyIncome               1000000
# MonthlyRate                 1000000
# NumCompaniesWorked          1000000
# Over18                      1000000
# OverTime                    1000000
# PercentSalaryHike           1000000
# PerformanceRating           1000000
# RelationshipSatisfaction    1000000
# ...

# %%
df.dropna().count()
# Out:
# Age                         1000000
# Attrition                   1000000
# BusinessTravel              1000000
# DailyRate                   1000000
# Department                  1000000
# DistanceFromHome            1000000
# Education                   1000000
# EducationField              1000000
# EmployeeCount               1000000
# EmployeeNumber              1000000
# EnvironmentSatisfaction     1000000
# Gender                      1000000
# HourlyRate                  1000000
# JobInvolvement              1000000
# JobLevel                    1000000
# JobRole                     1000000
# JobSatisfaction             1000000
# MaritalStatus               1000000
# MonthlyIncome               1000000
# MonthlyRate                 1000000
# NumCompaniesWorked          1000000
# Over18                      1000000
# OverTime                    1000000
# PercentSalaryHike           1000000
# PerformanceRating           1000000
# RelationshipSatisfaction    1000000
# ...

# %%
df['DailyRate']
# Out:
# 0          200
# 1          720
# 2         1406
# 3         1316
# 4          711
#           ...
# 999995     389
# 999996    1248
# 999997    1298
# 999998    1065
# 999999     776
# Name: DailyRate, Length: 1000000, dtype: int64

# %%
df.loc[18]
# Out:
# Age                                             25
# Attrition                                       No
# BusinessTravel                          Non-Travel
# DailyRate                                     1462
# Department                         Human Resources
# DistanceFromHome                                24
# Education                                        5
# EducationField                           Marketing
# EmployeeCount                                    1
# EmployeeNumber                                  19
# EnvironmentSatisfaction                          1
# Gender                                        Male
# HourlyRate                                     175
# JobInvolvement                                   4
# JobLevel                                         1
# JobRole                     Manufacturing Director
# JobSatisfaction                                  2
# MaritalStatus                               Single
# ...

# %%
df[['StandardHours','OverTime']]
# Out:
#         StandardHours OverTime
# 0                  80       No
# 1                  80      Yes
# 2                  80      Yes
# 3                  80      Yes
# 4                  80      Yes
# ...               ...      ...
# 999995             80       No
# 999996             80       No
# 999997             80       No
# 999998             80      Yes
# 999999             80      Yes
#
# [1000000 rows x 2 columns]

# %%
df.loc[18:38]
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 18   25        No         Non-Travel       1462         Human Resources
# 19   31       Yes      Travel_Rarely       1015                Software
# 20   33        No      Travel_Rarely        261                Software
# 21   30        No         Non-Travel       1188                Software
# 22   26       Yes      Travel_Rarely        496                Hardware
# 23   54       Yes         Non-Travel        693                 Support
# 24   44       Yes  Travel_Frequently       1127                Hardware
# 25   55       Yes      Travel_Rarely       1373                   Sales
# 26   59       Yes      Travel_Rarely        942                Software
# 27   60        No      Travel_Rarely       1009         Human Resources
# 28   40        No         Non-Travel       1148  Research & Development
# 29   46       Yes      Travel_Rarely        892                Hardware
# ...

# %%
df.iloc[[2,4,-1]]
# Out:
#         Age Attrition BusinessTravel  DailyRate              Department  \
# 2        25        No     Non-Travel       1406                 Support
# 4        35        No  Travel_Rarely        711  Research & Development
# 999999   19       Yes     Non-Travel        776  Research & Development
#
#         DistanceFromHome  Education    EducationField  EmployeeCount  \
# 2                      3          2     Life Sciences              1
# 4                     28          4  Technical Degree              1
# 999999                23          4   Human Resources              1
#
#         EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 2                    3  ...                         3            80
# 4                    5  ...                         4            80
# 999999         1000000  ...                         1            80
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df.drop(35)
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0        58        No  Travel_Frequently        200                Hardware
# 1        18       Yes      Travel_Rarely        720                   Sales
# 2        25        No         Non-Travel       1406                 Support
# 3        38       Yes  Travel_Frequently       1316                Software
# 4        35        No      Travel_Rarely        711  Research & Development
# ...     ...       ...                ...        ...                     ...
# 999995   19       Yes      Travel_Rarely        389                   Sales
# 999996   24        No         Non-Travel       1248                Hardware
# 999997   55        No         Non-Travel       1298                 Support
# 999998   44       Yes         Non-Travel       1065  Research & Development
# 999999   19       Yes         Non-Travel        776  Research & Development
#
# ...

# %%
df.drop(['Department', 'Education'], axis=1) # refers to column
# Out:
#         Age Attrition     BusinessTravel  DailyRate  DistanceFromHome  \
# 0        58        No  Travel_Frequently        200                13
# 1        18       Yes      Travel_Rarely        720                34
# 2        25        No         Non-Travel       1406                 3
# 3        38       Yes  Travel_Frequently       1316                19
# 4        35        No      Travel_Rarely        711                28
# ...     ...       ...                ...        ...               ...
# 999995   19       Yes      Travel_Rarely        389                22
# 999996   24        No         Non-Travel       1248                 7
# 999997   55        No         Non-Travel       1298                33
# 999998   44       Yes         Non-Travel       1065                34
# 999999   19       Yes         Non-Travel        776                23
#
#           EducationField  EmployeeCount  EmployeeNumber  \
# 0          Life Sciences              1               1
# ...

# %%
df.drop([35, 25], axis=0) # refers to row
# Out:
#         Age Attrition     BusinessTravel  DailyRate              Department  \
# 0        58        No  Travel_Frequently        200                Hardware
# 1        18       Yes      Travel_Rarely        720                   Sales
# 2        25        No         Non-Travel       1406                 Support
# 3        38       Yes  Travel_Frequently       1316                Software
# 4        35        No      Travel_Rarely        711  Research & Development
# ...     ...       ...                ...        ...                     ...
# 999995   19       Yes      Travel_Rarely        389                   Sales
# 999996   24        No         Non-Travel       1248                Hardware
# 999997   55        No         Non-Travel       1298                 Support
# 999998   44       Yes         Non-Travel       1065  Research & Development
# 999999   19       Yes         Non-Travel        776  Research & Development
#
# ...

# %%
df['New_Daily_Rate'] = df['DailyRate']/1.05

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   58        No  Travel_Frequently        200                Hardware
# 1   18       Yes      Travel_Rarely        720                   Sales
# 2   25        No         Non-Travel       1406                 Support
# 3   38       Yes  Travel_Frequently       1316                Software
# 4   35        No      Travel_Rarely        711  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                13          5     Life Sciences              1
# 1                34          2  Technical Degree              1
# 2                 3          2     Life Sciences              1
# 3                19          5             Other              1
# 4                28          4  Technical Degree              1
#
#    EmployeeNumber  ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 0               1  ...             80                4                 40
# ...

# %%
df.drop([190.47619047619048,685.7142857142857,1339.047619047619,1253.3333333333333,677.1428571428571], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1e4fe3afbe87> in <module>
# ----> 1 df.drop([190.47619047619048,685.7142857142857,1339.047619047619,1253.3333333333333,677.1428571428571], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
DailyRate = df['DailyRate']

# %%
DailyRate.min(), DailyRate.max()
# Out:
# (100, 1500)

# %%
x = DailyRate.sum()

# %%
y =len(DailyRate)

# %%
x/y
# Out:
# 799.498643

# %%
DailyRate.mean()
# Out:
# 799.498643

# %%
DailyRate.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0          200
# 1          720
# 2         1406
# 3         1316
# 4          711
#           ...
# 999995     389
# 999996    1248
# 999997    1298
# 999998    1065
# 999999     776
# Name: DailyRate, Length: 1000000, dtype: int64>

# %%
DailyRate.median()
# Out:
# 799.0

# %%
DailyRate.describe()
# Out:
# count    1000000.000000
# mean         799.498643
# std          404.493606
# min          100.000000
# 25%          449.000000
# 50%          799.000000
# 75%         1150.000000
# max         1500.000000
# Name: DailyRate, dtype: float64

# %%
df.reset_index()
# Out:
#          index  Age Attrition     BusinessTravel  DailyRate  \
# 0            0   58        No  Travel_Frequently        200
# 1            1   18       Yes      Travel_Rarely        720
# 2            2   25        No         Non-Travel       1406
# 3            3   38       Yes  Travel_Frequently       1316
# 4            4   35        No      Travel_Rarely        711
# ...        ...  ...       ...                ...        ...
# 999995  999995   19       Yes      Travel_Rarely        389
# 999996  999996   24        No         Non-Travel       1248
# 999997  999997   55        No         Non-Travel       1298
# 999998  999998   44       Yes         Non-Travel       1065
# 999999  999999   19       Yes         Non-Travel        776
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                     Hardware                13          5     Life Sciences
# 1                        Sales                34          2  Technical Degree
# ...

# %%
df.set_index('Age')
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 58         No  Travel_Frequently        200                Hardware
# 18        Yes      Travel_Rarely        720                   Sales
# 25         No         Non-Travel       1406                 Support
# 38        Yes  Travel_Frequently       1316                Software
# 35         No      Travel_Rarely        711  Research & Development
# ..        ...                ...        ...                     ...
# 19        Yes      Travel_Rarely        389                   Sales
# 24         No         Non-Travel       1248                Hardware
# 55         No         Non-Travel       1298                 Support
# 44        Yes         Non-Travel       1065  Research & Development
# 19        Yes         Non-Travel        776  Research & Development
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# Age
# 58                 13          5     Life Sciences              1
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   58        No  Travel_Frequently        200                Hardware
# 1   18       Yes      Travel_Rarely        720                   Sales
# 2   25        No         Non-Travel       1406                 Support
# 3   38       Yes  Travel_Frequently       1316                Software
# 4   35        No      Travel_Rarely        711  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                13          5     Life Sciences              1
# 1                34          2  Technical Degree              1
# 2                 3          2     Life Sciences              1
# 3                19          5             Other              1
# 4                28          4  Technical Degree              1
#
#    EmployeeNumber  ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# 0               1  ...             80                4                 40
# ...

# %%
plt.plot(df.index, df['DailyRate'])

# %%
df['DailyRate'].plot(kind = 'box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
df['DailyRate'].plot(kind='density', figsize=(14,6))
plt.show()

# %%
df['DailyRate'].value_counts()
# Out:
# 331     806
# 538     798
# 534     784
# 303     782
# 301     782
#        ...
# 1432    649
# 1006    647
# 1183    646
# 1382    637
# 383     635
# Name: DailyRate, Length: 1401, dtype: int64

# %%
df['DailyRate'].mean()
# Out:
# 799.498643

# %%
df['DailyRate'].value_counts().plot(kind = 'pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='DailyRate'>
